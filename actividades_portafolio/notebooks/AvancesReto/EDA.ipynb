# %% [markdown]
# # EDA

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
testndata = pd.read_csv("../data/raw/mitbih_train.csv",header=None)
traindata = pd.read_csv("../data/raw/mitbih_test.csv",header=None)

# %%
traindata.shape
# Out:
# (21892, 188)

# %%
testndata.shape
# Out:
# (87554, 188)

# %%
print('train set classes: ', traindata.iloc[:, -1].unique())
print('train set classes: ', testndata.iloc[:, -1].unique())
# Out:
# train set classes:  [0. 1. 2. 3. 4.]
# train set classes:  [0. 1. 2. 3. 4.]

# %% [markdown]
# Clasificaciones
#
# 0: "Normal",
#
# 1: "Artial Premature",
#
# 2: "Premature ventricular contraction",
#
# 3: "Fusion of ventricular and normal",
#
# 4: "Fusion of paced and normal"

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Renombrar las clases utilizando el diccionario labels
traindata['class_name'] = traindata.iloc[:, -1].map(labels)

# Contar el número de muestras por clase
value_counts = traindata['class_name'].value_counts()

# Crear la gráfica de barras usando seaborn
plt.figure(figsize=(10, 6))
sns.barplot(x=value_counts.index, y=value_counts.values, palette='viridis')
plt.title("The Count of Each Label in The Train Dataset", fontsize=16)
plt.xlabel('Labels', fontsize=14)
plt.ylabel('Counts', fontsize=14)
plt.xticks(rotation=45)
plt.show()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 5
#       2 import seaborn as sns
#       4 # Renombrar las clases utilizando el diccionario labels
# ----> 5 traindata['class_name'] = traindata.iloc[:, -1].map(labels)
#       7 # Contar el número de muestras por clase
#       8 value_counts = traindata['class_name'].value_counts()
#
# NameError: name 'labels' is not defined

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Renombrar las clases utilizando el diccionario labels
traindata['class_name'] = testndata.iloc[:, -1].map(labels)

# Contar el número de muestras por clase
value_counts = traindata['class_name'].value_counts()

# Crear la gráfica de barras usando seaborn
plt.figure(figsize=(10, 6))
sns.barplot(x=value_counts.index, y=value_counts.values, palette='viridis')
plt.title("The Count of Each Label in The Train Dataset", fontsize=16)
plt.xlabel('Labels', fontsize=14)
plt.ylabel('Counts', fontsize=14)
plt.xticks(rotation=45)
plt.show()

plt.show()
# Out:
# C:\Users\crist\AppData\Local\Temp\ipykernel_23016\107641353.py:12: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
# Excluir la última columna (labels) antes de calcular la matriz de correlación
correlation_matrix = traindata.iloc[:, :-1].corr()

# Crear el mapa de calor de la matriz de correlación
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=False, cmap='coolwarm')
plt.title('Correlation Matrix of Features')
plt.show()
